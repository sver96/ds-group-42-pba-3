# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Sarel's dataset
df = pd.read_csv('C:/Users/lmost/OneDrive/Desktop/PBA3/Sarel_dataset/kidney_disease.csv', engine='python')
#df = pd.read_csv('Sarel_dataset/kidney_disease.csv', engine='python') #relative path?
print(df.head())

df['classification'] = df['classification'].str.strip()

# Inspect data types
print(df.dtypes)

for column in df.columns:
    print(column, df[column].unique())

# Replace '' with NaN
df.replace('', pd.NA, inplace=True)

# Check for missing values
print(df.isnull().sum())

# Summary statistics
print(df.describe())

# Check for duplicate rows
print(df.duplicated().sum())

import seaborn as sns
import matplotlib.pyplot as plt

import seaborn as sns
import matplotlib.pyplot as plt

# Histogram of a column
sns.histplot(df['classification'], kde=True)
plt.xticks(rotation=90)
plt.show()

# Histogram of a column
sns.histplot(df['rbc'], kde=True)
plt.xlabel('Red Blood Cells')
plt.xticks(rotation=90)
plt.show()

# Histogram of a column
sns.histplot(df['pc'], kde=True)
plt.xlabel('Puss Cell')
plt.xticks(rotation=90)
plt.show()

# Histogram of a column
sns.histplot(df['pcc'], kde=True)
plt.xlabel('Puss Cell Clumps')
plt.xticks(rotation=90)
plt.show()

# Boxplot for numerical columns
sns.boxplot(x=df['age'])
plt.show()

# Boxplot for numerical columns
sns.boxplot(x=df['bp'])
plt.xlabel('Blood Pressure')
plt.show()

# Boxplot for numerical columns
sns.boxplot(x=df['sg'])
plt.xlabel('Specific Gravity')
plt.show()

# Boxplot for numerical columns
sns.boxplot(x=df['al'])
plt.xlabel('Albumin')
plt.show()

# Boxplot for numerical columns
sns.boxplot(x=df['su'])
plt.xlabel('Sugar')
plt.show()

#NB click view as scrollable element
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]
# id                  int64
# age               float64
# ...

# %%
#Data set 2 -> Salary
# Load the data
df_2 = pd.read_csv('C:/Users/lmost/OneDrive/Desktop/PBA3/Dataset 2/salary.csv', engine='python')
#df_2 = pd.read_csv('Dataset 2/salary.csv', engine='python') #relative path?
print(df_2.head())

df_2.rename(columns=lambda x: x.replace('-', '_'), inplace=True)

# Inspect data types
print(df_2.dtypes)

# Replace '?' with NaN
df_2.replace(' ?', pd.NA, inplace=True)

# Check for missing values
print(df_2.isnull().sum())

# Summary statistics
print(df_2.describe())

# Check for duplicate rows
print(df_2.duplicated().sum())

for column in df_2.columns:
    print(column, df_2[column].unique())

    import seaborn as sns
import matplotlib.pyplot as plt

import seaborn as sns
import matplotlib.pyplot as plt

# Histogram of a column
sns.histplot(df_2['salary'], kde=True)
plt.xticks(rotation=90)
plt.show()

# Histogram of a column
sns.histplot(df_2['workclass'], kde=True)
plt.xticks(rotation=90)
plt.show()

# Histogram of a column
sns.histplot(df_2['education'], kde=True)
plt.xticks(rotation=90)
plt.show()

# Histogram of a column
sns.histplot(df_2['marital_status'], kde=True)
plt.xticks(rotation=90)
plt.show()

# Histogram of a column
sns.histplot(df_2['occupation'], kde=True)
plt.xticks(rotation=90)
plt.show()

# Histogram of a column
sns.histplot(df_2['relationship'], kde=True)
plt.xticks(rotation=90)
plt.show()

# Histogram of a column
sns.histplot(df_2['race'], kde=True)
plt.xticks(rotation=90)
plt.show()

# Histogram of a column
sns.histplot(df_2['sex'], kde=True)
plt.xticks(rotation=90)
plt.show()

# Histogram of a column
sns.histplot(df_2['native_country'], kde=True)
plt.xticks(rotation=90)
plt.show()

# Boxplot for numerical columns
sns.boxplot(x=df_2['hours_per_week'])
plt.show()

# Boxplot for numerical columns
sns.boxplot(x=df_2['capital_loss'])
plt.show()

# Boxplot for numerical columns
sns.boxplot(x=df_2['capital_gain'])
plt.show()

# Boxplot for numerical columns
sns.boxplot(x=df_2['age'])
plt.show()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# ...
